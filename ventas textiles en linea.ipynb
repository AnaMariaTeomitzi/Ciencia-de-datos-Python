# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaMariaTeomitzi/Ciencia-de-datos-Python/blob/main/ventas%20textiles%20en%20linea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Cargar el archivo de Excel a un DataFrame
# Reemplaza 'ventas_tienda.xlsx' por el nombre EXACTO de tu archivo entre comillas
df_mis_ventas = pd.read_excel('/ventasjulio2026.xlsx')

# Revisar las primeras 5 filas para verificar que cargó bien
print("--- PRIMERAS FILAS DE MI EXCEL ---")
print(df_mis_ventas.head())

# cuenta cuentas colunmas hay en nuestro excel
filas, columnas = df_mis_ventas.shape

print(f"Tu tabla tiene un total de {filas} ventas registradas y {columnas} columnas.")

# 1. Ver qué columnas tiene la tabla
print("--- COLUMNAS DE LA TABLA ---")
print(df_mis_ventas.columns.tolist())

# 2. Ver cuántas ventas hay en total y qué tipo de datos son
print("\n--- RESUMEN GENERAL ---")
print(df_mis_ventas.info())

# Ver si hay celdas vacías en alguna columna
print("--- DATOS FALTANTES POR COLUMNA ---")
print(df_mis_ventas.isnull().sum())

# Ver las primeras 3 filas de la tabla
print("\n--- MUESTRA DE DATOS ---")
print(df_mis_ventas.head(3))

# Muestra las primeras 5 filas de una sola columna
print(df_mis_ventas['Título de la publicación'].head())

# 1. MÉTRICAS GENERALES (KPIs)
# ==========================================
# Sustituye 'Ingresos por ventas (MXN)' y 'Unidades' por los nombres exactos de tus columnas
total_ingresos = df_mis_ventas['Ingresos por productos (MXN)'].sum()
total_unidades = df_mis_ventas['Unidades'].sum()
ticket_promedio = df_mis_ventas['Ingresos por productos (MXN)'].mean()

print("--- RESUMEN EJECUTIVO ---")
print(f"Total vendido: ${total_ingresos:,.2f} MXN")
print(f"Total unidades vendidas: {total_unidades:,} piezas")
print(f"Venta promedio por transacción: ${ticket_promedio:,.2f} MXN")

# ==========================================
# 2. TOP 5 PRODUCTOS MÁS VENDIDOS
# ==========================================
print("\n--- TOP 5 PRODUCTOS (POR UNIDADES) ---")
top_unidades = (
    df_mis_ventas.groupby('Título de la publicación')['Unidades']
    .sum()
    .sort_values(ascending=False)
    .head(5)
)
print(top_unidades)

print("\n--- TOP 5 PRODUCTOS (POR INGRESOS) ---")
top_ingresos = (
    df_mis_ventas.groupby('Título de la publicación')['Ingresos por productos (MXN)']
    .sum()
    .sort_values(ascending=False)
    .head(5)
)
print(top_ingresos)
# Out:
# --- PRIMERAS FILAS DE MI EXCEL ---
#          # de venta                  Fecha de venta            Estado  \
# 0  2000014499413725  12 de agosto de 2026 13:30 hs.  Etiqueta impresa
# 1  2000014494580737  12 de agosto de 2026 08:58 hs.  Etiqueta impresa
# 2  2000014489072265  11 de agosto de 2026 21:31 hs.         En camino
# 3  2000014484597341  11 de agosto de 2026 16:56 hs.         En camino
# 4  2000014483778057  11 de agosto de 2026 16:09 hs.         En camino
#
#                               Descripción del estado  \
# 0  Tienes que entregar el paquete mañana en una a...
# 1  Tienes que entregar el paquete mañana en una a...
# 2                   Llega entre el 14 y 15 de agosto
# 3                      Llega el viernes 14 de agosto
# 4                   Llega entre el 14 y 15 de agosto
#
#   Paquete de varios productos Pertenece a un kit  Unidades  \
# 0                          Sí                 No       1.0
# 1                          Sí                 No       1.0
# 2                          Sí                 No       1.0
# 3                          Sí                 No       1.0
# 4                          Sí                 No       1.0
#
#    Ingresos por productos (MXN)  Cargo por venta e impuestos (MXN)  \
# 0                         613.0                            -156.63
# 1                         460.0                            -131.33
# 2                         396.0                             -95.24
# 3                         510.0                            -145.61
# 4                         249.0                             -71.10
#
#    Ingresos por envío (MXN)  ...  Revisado por Mercado Libre  \
# 0                       NaN  ...
# 1                       NaN  ...
# 2                       NaN  ...
# 3                       NaN  ...
# 4                       NaN  ...
#
#    Fecha de revisión  Dinero a favor  Resultado  Destino  \
# 0
# 1
# 2
# 3
# 4
#
#    Motivo del resultado Unidades.2 Reclamo abierto Reclamo cerrado  \
# 0                              NaN              No             NaN
# 1                              NaN              No             NaN
# 2                              NaN              No             NaN
# 3                              NaN              No             NaN
# 4                              NaN              No             NaN
#
#   Con mediación
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 63 columns]
# Tu tabla tiene un total de 140 ventas registradas y 63 columnas.
# --- COLUMNAS DE LA TABLA ---
# ['# de venta', 'Fecha de venta', 'Estado', 'Descripción del estado', 'Paquete de varios productos', 'Pertenece a un kit', 'Unidades', 'Ingresos por productos (MXN)', 'Cargo por venta e impuestos (MXN)', 'Ingresos por envío (MXN)', 'Costos de envío (MXN)', 'Costo de envío basado en medidas y peso declarados', 'Cargo por diferencias en medidas y peso del paquete', 'Descuentos y bonificaciones', 'Anulaciones y reembolsos (MXN)', 'Total (MXN)', 'Orden de compra', 'Venta por publicidad', 'SKU', '# de publicación', 'Título de la publicación', 'Variante', 'Precio unitario de venta de la publicación (MXN)', 'Tipo de publicación', 'Factura adjunta', 'Datos personales o de empresa', 'Tipo y número de documento', 'Dirección', 'Tipo de contribuyente', 'CFDI', 'Tipo de usuario', 'Régimen Fiscal', 'Comprador', 'Negocio', 'IFE', 'Domicilio', 'Municipio/Alcaldía', 'Estado.1', 'Código postal', 'País', 'Forma de entrega', 'Fecha en camino', 'Fecha entregado', 'Transportista', 'Número de seguimiento', 'URL de seguimiento', 'Unidades.1', 'Forma de entrega.1', 'Fecha en camino.1', 'Fecha entregado.1', 'Transportista.1', 'Número de seguimiento.1', 'URL de seguimiento.1', 'Revisado por Mercado Libre', 'Fecha de revisión', 'Dinero a favor', 'Resultado', 'Destino', 'Motivo del resultado', 'Unidades.2', 'Reclamo abierto', 'Reclamo cerrado', 'Con mediación']
#
# --- RESUMEN GENERAL ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 63 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   # de venta                                           140 non-null    int64
#  1   Fecha de venta                                       140 non-null    object
#  2   Estado                                               140 non-null    object
#  3   Descripción del estado                               140 non-null    object
#  4   Paquete de varios productos                          140 non-null    object
#  5   Pertenece a un kit                                   140 non-null    object
#  6   Unidades                                             134 non-null    float64
#  7   Ingresos por productos (MXN)                         127 non-null    float64
#  8   Cargo por venta e impuestos (MXN)                    127 non-null    float64
#  9   Ingresos por envío (MXN)                             2 non-null      float64
#  10  Costos de envío (MXN)                                127 non-null    float64
#  11  Costo de envío basado en medidas y peso declarados   0 non-null      float64
#  12  Cargo por diferencias en medidas y peso del paquete  0 non-null      float64
#  13  Descuentos y bonificaciones                          0 non-null      float64
#  14  Anulaciones y reembolsos (MXN)                       4 non-null      float64
#  15  Total (MXN)                                          127 non-null    float64
#  16  Orden de compra                                      140 non-null    object
#  17  Venta por publicidad                                 140 non-null    object
#  18  SKU                                                  140 non-null    object
#  19  # de publicación                                     140 non-null    object
#  20  Título de la publicación                             140 non-null    object
#  21  Variante                                             140 non-null    object
#  22  Precio unitario de venta de la publicación (MXN)     134 non-null    float64
#  23  Tipo de publicación                                  140 non-null    object
#  24  Factura adjunta                                      140 non-null    object
#  25  Datos personales o de empresa                        140 non-null    object
#  26  Tipo y número de documento                           140 non-null    object
#  27  Dirección                                            140 non-null    object
#  28  Tipo de contribuyente                                140 non-null    object
#  29  CFDI                                                 140 non-null    object
#  30  Tipo de usuario                                      140 non-null    object
#  31  Régimen Fiscal                                       140 non-null    object
#  32  Comprador                                            140 non-null    object
#  33  Negocio                                              140 non-null    object
#  34  IFE                                                  140 non-null    object
#  35  Domicilio                                            140 non-null    object
#  36  Municipio/Alcaldía                                   140 non-null    object
#  37  Estado.1                                             140 non-null    object
#  38  Código postal                                        140 non-null    object
#  39  País                                                 140 non-null    object
#  40  Forma de entrega                                     140 non-null    object
#  41  Fecha en camino                                      140 non-null    object
#  42  Fecha entregado                                      140 non-null    object
#  43  Transportista                                        140 non-null    object
#  44  Número de seguimiento                                140 non-null    object
#  45  URL de seguimiento                                   140 non-null    object
#  46  Unidades.1                                           139 non-null    object
#  47  Forma de entrega.1                                   140 non-null    object
#  48  Fecha en camino.1                                    140 non-null    object
#  49  Fecha entregado.1                                    140 non-null    object
#  50  Transportista.1                                      140 non-null    object
#  51  Número de seguimiento.1                              140 non-null    object
#  52  URL de seguimiento.1                                 140 non-null    object
#  53  Revisado por Mercado Libre                           140 non-null    object
#  54  Fecha de revisión                                    140 non-null    object
#  55  Dinero a favor                                       140 non-null    object
#  56  Resultado                                            140 non-null    object
#  57  Destino                                              140 non-null    object
#  58  Motivo del resultado                                 140 non-null    object
#  59  Unidades.2                                           0 non-null      float64
#  60  Reclamo abierto                                      140 non-null    object
#  61  Reclamo cerrado                                      2 non-null      float64
#  62  Con mediación                                        140 non-null    object
# dtypes: float64(13), int64(1), object(49)
# memory usage: 69.0+ KB
# None
# --- DATOS FALTANTES POR COLUMNA ---
# # de venta                       0
# Fecha de venta                   0
# Estado                           0
# Descripción del estado           0
# Paquete de varios productos      0
#                               ...
# Motivo del resultado             0
# Unidades.2                     140
# Reclamo abierto                  0
# Reclamo cerrado                138
# Con mediación                    0
# Length: 63, dtype: int64
#
# --- MUESTRA DE DATOS ---
#          # de venta                  Fecha de venta            Estado  \
# 0  2000014499413725  12 de agosto de 2026 13:30 hs.  Etiqueta impresa
# 1  2000014494580737  12 de agosto de 2026 08:58 hs.  Etiqueta impresa
# 2  2000014489072265  11 de agosto de 2026 21:31 hs.         En camino
#
#                               Descripción del estado  \
# 0  Tienes que entregar el paquete mañana en una a...
# 1  Tienes que entregar el paquete mañana en una a...
# 2                   Llega entre el 14 y 15 de agosto
#
#   Paquete de varios productos Pertenece a un kit  Unidades  \
# 0                          Sí                 No       1.0
# 1                          Sí                 No       1.0
# 2                          Sí                 No       1.0
#
#    Ingresos por productos (MXN)  Cargo por venta e impuestos (MXN)  \
# 0                         613.0                            -156.63
# 1                         460.0                            -131.33
# 2                         396.0                             -95.24
#
#    Ingresos por envío (MXN)  ...  Revisado por Mercado Libre  \
# 0                       NaN  ...
# 1                       NaN  ...
# 2                       NaN  ...
#
#    Fecha de revisión  Dinero a favor  Resultado  Destino  \
# 0
# 1
# 2
#
#    Motivo del resultado Unidades.2 Reclamo abierto Reclamo cerrado  \
# 0                              NaN              No             NaN
# 1                              NaN              No             NaN
# 2                              NaN              No             NaN
#
#   Con mediación
# 0            No
# 1            No
# 2            No
#
# [3 rows x 63 columns]
# 0                       Tela Indiolino (5 M) Azul Liso
# 1    Sábanas Matrimonial Microfibra Suave Premium P...
# 2    Frazada Sin Borrega Matrimonial Spiderman Spid...
# 3    Blancos Azteca Sábanas Matrimoniales Microfibr...
# 4                          Colcha Economica Individual
# Name: Título de la publicación, dtype: object
# --- RESUMEN EJECUTIVO ---
# Total vendido: $97,316.81 MXN
# Total unidades vendidas: 141.0 piezas
# Venta promedio por transacción: $766.27 MXN
#
# --- TOP 5 PRODUCTOS (POR UNIDADES) ---
# Título de la publicación
# Sábanas Matrimonial Algodón                                                                     15.0
# Colcha Economica Individual                                                                     12.0
# Juego De Sábanas Suavi Kotton Franela Matrimonial.                                               9.0
# Sabana Individual Algodon Percal                                                                 8.0
# Juego De Sábanas Individual Suave Blancos Azteca Color Corazones Diseño De La Tela Estampado     7.0
# Name: Unidades, dtype: float64
#
# --- TOP 5 PRODUCTOS (POR INGRESOS) ---
# Título de la publicación
# Sabana De Algodon King Size Carmen (10 Piezas) Varios             10440.00
# Tela Indiolino Azul (20 M) Azul Liso                              10231.20
#                                                                    5668.08
# Sábanas Matrimonial Algodón                                        5208.66
# Pack 10 Juegos De Sabana Algodon (7 Matri Y 3 Indi) Liso,estam     3900.00
# Name: Ingresos por productos (MXN), dtype: float64
