# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaMariaTeomitzi/Ciencia-de-datos-Python/blob/main/Copia_de_ventas_textiles_en_linea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Cargar el archivo de Excel a un DataFrame
# Reemplaza 'ventas_tienda.xlsx' por el nombre EXACTO de tu archivo entre comillas
df_mis_ventas = pd.read_excel('/eneroagosto2026ventas.xlsx')

# Revisar las primeras 5 filas para verificar que cargó bien
print("--- PRIMERAS FILAS DE MI EXCEL ---")
print(df_mis_ventas.head())

# cuenta cuentas colunmas hay en nuestro excel
filas, columnas = df_mis_ventas.shape

print(f"Tu tabla tiene un total de {filas} ventas registradas y {columnas} columnas.")

# 1. Ver qué columnas tiene la tabla
print("--- COLUMNAS DE LA TABLA ---")
print(df_mis_ventas.columns.tolist())

# 2. Ver cuántas ventas hay en total y qué tipo de datos son
print("\n--- RESUMEN GENERAL ---")
print(df_mis_ventas.info())

# Ver si hay celdas vacías en alguna columna
print("--- DATOS FALTANTES POR COLUMNA ---")
print(df_mis_ventas.isnull().sum())
# Out:
# --- PRIMERAS FILAS DE MI EXCEL ---
#    CANTIDAD                              CONCEPTO  COSTO  SUBTOTAL categoria
# 0        20  Tela Indiolino Azul (20 M) Azul Liso   48.0     960.0      tela
# 1         2              Colcha Oaxaca (2 Piezas)   88.0     176.0   colchas
# 2        20  Tela Indiolino Azul (20 M) Azul Liso   48.0     960.0      tela
# 3         5        Tela Indiolino (5 M) Azul Liso   48.0     240.0      tela
# 4        20  Tela Indiolino Azul (20 M) Azul Liso   48.0     960.0      tela
# Tu tabla tiene un total de 265 ventas registradas y 5 columnas.
# --- COLUMNAS DE LA TABLA ---
# ['CANTIDAD', 'CONCEPTO', 'COSTO', 'SUBTOTAL', 'categoria']
#
# --- RESUMEN GENERAL ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CANTIDAD   265 non-null    int64
#  1   CONCEPTO   265 non-null    object
#  2   COSTO      265 non-null    float64
#  3   SUBTOTAL   265 non-null    float64
#  4   categoria  265 non-null    object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 10.5+ KB
# None
# --- DATOS FALTANTES POR COLUMNA ---
# CANTIDAD     0
# CONCEPTO     0
# COSTO        0
# SUBTOTAL     0
# categoria    0
# dtype: int64
